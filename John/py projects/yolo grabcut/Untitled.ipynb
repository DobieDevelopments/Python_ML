# %%
import cv2
#load cascade classifier training file for haarcascade
haar_face_cascade = cv2.CascadeClassifier('catfaces.xml')

# %%
def detect_faces(f_cascade, colored_img, scaleFactor = 1.1):
    #just making a copy of image passed, so that passed image is not changed
    img_copy = colored_img.copy()
    #convert the test image to gray image as opencv face detector expects gray images
    gray = cv2.cvtColor(img_copy, cv2.COLOR_BGR2GRAY)       
    #let's detect multiscale (some images may be closer to camera than others) images
    faces = f_cascade.detectMultiScale(gray, scaleFactor=scaleFactor, minNeighbors=5);   
    #go over list of faces and draw them as rectangles on original colored img
    for (x, y, w, h) in faces:
        cv2.rectangle(img_copy, (x, y), (x+w, y+h), (0, 255, 0), 2)
    return img_copy

# %%
import glob
import matplotlib.pyplot as plt
filenames = [img for img in glob.glob("images/*.jpg")]

filenames.sort()

images = []
for img in filenames:
    n= cv2.imread(img)
    images.append(n)
    print (img)

#load another image
for img in images:
    #call our function to detect faces
    faces_detected_img = detect_faces(haar_face_cascade, img)
    #convert image to RGB and show image
    plt.imshow(faces_detected_img)
    plt.show()
# Out:
# images\000a290e4-1.jpg
# images\000fb9572-4.jpg
# images\00a1f270a-3.jpg
# images\00af25fc0-2.jpg
# images\00b23513e-4.jpg
# images\00bfa5da9-1.jpg
# images\00c19f4fa-1.jpg
# images\00eca0391-1.jpg
# images\00f997463-6.jpg
# images\0a1b56e66-3.jpg
# images\0a4b42306-1.jpg

# %%
import tensorflow as tf
import numpy as np
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display
from seaborn import color_palette
import cv2
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
